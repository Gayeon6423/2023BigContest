# %%
#  데이터 처리 모듈
import pandas as pd
from sklearn.impute import KNNImputer
# 행렬 등 통계 연산 모듈
import numpy as np
# 지수형 표기법 e를 연속형 변환
pd.options.display.float_format = '{:.4f}'.format
# 타입 어노테이션(Any, Sequence 등의 메서드 활용)
from typing import *
import os

# 구글 드라이브 마운트
from google.colab import drive
drive.mount("/content/drive")
import os

# 조합 찾는 반복문 메서드
from itertools import permutations
from itertools import combinations

# 데이터 시각화
import matplotlib.pyplot as plt
# from matplotlib.pyplot import
import matplotlib.font_manager as fm
import missingno as msno
import seaborn as sns
# Out:
# Mounted at /content/drive

# %%
# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum

fe = fm.FontEntry(
    fname=r"/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
    # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')
# 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)
# Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'})
# 폰트 설정
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
class LoadGoogleDriveData():
  def __init__(self, data = None):
    self.data = data

  def loadData(self, file_path: str, file_name_extension,
               columnTF: bool, unicode: str) -> pd.DataFrame():
    self.data = pd.read_csv(os.path.join(file_path + file_name_extension),
                            index_col = columnTF,
                            na_values = "NaN",
                            encoding = unicode)
    return self.data

  # 용량이 큰 csv 파일 읽어오기(fopen - fread와 유사한 방식)
  def loadDataWithChunking(self, file_path: str, file_name_extension,
                           chunking_row_num: int, columnTF: bool, unicode: str) -> pd.DataFrame():
    chunkdata = pd.read_csv(os.path.join(file_path + file_name_extension),
                            chunksize = chunking_row_num,
                            index_col = columnTF,
                            na_values = "NaN",
                            encoding = unicode)
    self.data = list(chunkdata)
    return self.data

# %%
mountInstance = LoadGoogleDriveData()

# %% [markdown]
# ### 1.오아시스 비즈니스(필지고유번호 & 법정동읍면동코드 & 외식업종)  데이터

# %%
CONTEST_2023 = mountInstance.loadDataWithChunking(
    file_path = "/content/drive/MyDrive/2023BigContest/data/contest data/", file_name_extension = "소상공인 매출등급 예상 대상 필지.csv",
    unicode = "cp949", chunking_row_num = 10**5, columnTF = False)

# %%
CONTEST_2022 = mountInstance.loadDataWithChunking(
    file_path = "/content/drive/MyDrive/2023BigContest/data/contest data/", file_name_extension = "필지단위 소상공인 매출등급 정보.csv",
    unicode = "cp949", chunking_row_num = 10**5, columnTF = False)

# %% [markdown]
# ### 2. KCD(상권코드 & 외식업종 중분류) 소상공인 신용데이터

# %%
KCD_2022_2023 = mountInstance.loadData(
    file_path = "/content/drive/MyDrive/2023BigContest/data/DESILO_PLATFORM_DATA/", file_name_extension = "SOHO_MERGE_DATA_LIST.csv",
    unicode = "utf-8", columnTF = False)

# %% [markdown]
# ### 3. 행정동코드 - 상권코드 매핑 데이터

# %%
MARKET_LOC_MAP = mountInstance.loadData(
    file_path = "/content/drive/MyDrive/2023BigContest/data/",
    file_name_extension = "market_loc_map.csv",
    unicode = "euc-kr", columnTF = False)

# %%
MARKET_LOC_MAP
# Out:
#       상권_코드_2022  상권_코드_2023    행정동_코드    법정동_코드  STDG_EMD_CD
# 0        2110008     3110008  11110515  11110101     11110101
# 1        2110008     3110008  11110515  11110102     11110102
# 2        2110008     3110008  11110515  11110103     11110103
# 3        2110008     3110008  11110515  11110104     11110104
# 4        2110008     3110008  11110515  11110105     11110105
# ...          ...         ...       ...       ...          ...
# 3453     2130102     3130102  11230750  11230110     11230110
# 3454     2130166     3130166  11380590  11380107     11380107
# 3455     2130113     3130113  11260690  11260106     11260106
# 3456     2130124     3130124  11290780  11290138     11290138
# 3457     2001495     3001495  11710566  11710111     11710111
#
# [3458 rows x 5 columns]

# %% [markdown]
# ### 4. 서울열린데이터광장 상권특성 공공데이터

# %%
# 텍스트 파일 n개가 포함된 C(로컬디스크) 내 파일경로 설정
file_path = "/content/drive/MyDrive/2023BigContest/data" + "/" + "상권_2022"
# 파일경로 내 텍스트 파일명을 디렉토리 리스트에 저장
directory_상권_2022 = os.listdir(file_path)
print(directory_상권_2022, end = ", ")

data_상권특성_2022: List = [
    (directory_상권_2022[index].split("(")[1]).split(")")[0]
    for index in range(len(directory_상권_2022))
]
print("\n", data_상권특성_2022, end = ", ")
# Out:
# ['서울시 상권분석서비스(상권영역).csv', '서울시 상권분석서비스(상권배후지-아파트).csv', '서울시 상권분석서비스(상권-소득소비).csv', '서울시 상권분석서비스(상권-아파트).csv', '서울시 상권분석서비스(상권배후지-직장인구).csv', '서울시 상권분석서비스(상권배후지-점포).csv', '서울시 상권분석서비스(상권-점포).csv', '서울시 상권분석서비스(상권배후지-집객시설).csv', '서울시 상권분석서비스(버스 총 승차 승객수 정보).csv', '서울시 상권분석서비스(상권배후지-생활인구).csv', '서울시 상권분석서비스(지하철 총 승차 승객수 정보).csv', '서울시 상권분석서비스(상권-생활인구).csv', '서울시 상권분석서비스(상권-직장인구).csv', '서울시 상권분석서비스(행정동별 상권변화지표).csv', '서울시 상권분석서비스(상권배후지-소득소비).csv'],
#  ['상권영역', '상권배후지-아파트', '상권-소득소비', '상권-아파트', '상권배후지-직장인구', '상권배후지-점포', '상권-점포', '상권배후지-집객시설', '버스 총 승차 승객수 정보', '상권배후지-생활인구', '지하철 총 승차 승객수 정보', '상권-생활인구', '상권-직장인구', '행정동별 상권변화지표', '상권배후지-소득소비'],

# %%
# 텍스트 파일 n개가 포함된 C(로컬디스크) 내 파일경로 설정
file_path = "/content/drive/MyDrive/2023BigContest/data" + "/" + "상권_2023"
# 파일경로 내 텍스트 파일명을 디렉토리 리스트에 저장
directory_상권_2023 = os.listdir(file_path)
print(directory_상권_2023, end = ",")

data_상권특성_2023: List = [
    (directory_상권_2023[index].split("(")[1]).split(")")[0]
    for index in range(len(directory_상권_2023))
]
print("\n", data_상권특성_2023, end = ", ")
# Out:
# ['서울시 상권분석서비스(상권배후지-점포)_2023.csv', '서울시 상권분석서비스(상권-점포)_2023.csv', '서울시 상권분석서비스(행정동별 상권변화지표)_2023.csv', '서울시 상권분석서비스(상권배후지-직장인구)_2023.csv', '서울시 상권분석서비스(상권-직장인구)_2023.csv', '서울시 상권분석서비스(상권-아파트)_2023.csv', '서울시 상권분석서비스(상권배후지-아파트)_2023.csv', '서울시 상권분석서비스(버스 총 승차 승객수 정보)_2023.csv', '서울시 상권분석서비스(지하철 총 승차 승객수 정보)_2023.csv', '서울시 상권분석서비스(상권배후지-생활인구)_2023.csv', '서울시 상권분석서비스(상권-생활인구)_2023.csv', '서울시 상권분석서비스(상권-소득소비)_2023.csv', '서울시 상권분석서비스(상권배후지-집객시설)_2023.csv'],
#  ['상권배후지-점포', '상권-점포', '행정동별 상권변화지표', '상권배후지-직장인구', '상권-직장인구', '상권-아파트', '상권배후지-아파트', '버스 총 승차 승객수 정보', '지하철 총 승차 승객수 정보', '상권배후지-생활인구', '상권-생활인구', '상권-소득소비', '상권배후지-집객시설'],

# %%
# 상권특성_2022 및 상권특성_2023 데이터의 교집합
print(np.intersect1d(data_상권특성_2022, data_상권특성_2023))
# 상권특성_2022 및 상권특성_2023 데이터의 여집합
# Out:
# ['버스 총 승차 승객수 정보' '상권-생활인구' '상권-소득소비'
#  '상권-아파트' '상권-점포' '상권-직장인구'
#  '상권배후지-생활인구' '상권배후지-아파트' '상권배후지-점포'
#  '상권배후지-직장인구' '상권배후지-집객시설'
#  '지하철 총 승차 승객수 정보' '행정동별 상권변화지표']

# %%
print(np.setxor1d(data_상권특성_2022, data_상권특성_2023))
# Out:
# ['상권배후지-소득소비' '상권영역']

# %%
directory_상권_2022.remove("서울시 상권분석서비스(상권배후지-소득소비).csv")
data_상권특성_2022.remove("상권배후지-소득소비")

# %%
MARKET_2022_LIST = []
for index, data in zip(list(range(len(directory_상권_2022))), directory_상권_2022):
  MARKET_2022 = mountInstance.loadData(
    file_path = "/content/drive/MyDrive/2023BigContest/data/상권_2022/",
    file_name_extension = data,
    unicode = "euc-kr", columnTF = False)
  MARKET_2022_LIST.append(MARKET_2022)
  MARKET_2022 = 0

# %%
MARKET_2023_LIST = []
directory_상권_2023: List = [item.split(".csv")[0] + "_2023.csv" for item in directory_상권_2022[1:]]

for index, data in zip(list(range(len(directory_상권_2023))), directory_상권_2023):
  MARKET_2023 = mountInstance.loadData(
    file_path = "/content/drive/MyDrive/2023BigContest/data/상권_2023/",
    file_name_extension = data,
    unicode = "euc-kr", columnTF = False)
  MARKET_2023_LIST.append(MARKET_2023)
  MARKET_2023 = 0
# Out:
# <ipython-input-3-2f3715f5efe7>:7: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(os.path.join(file_path + file_name_extension),

# %%
display(directory_상권_2022)
# MARKET_2022_LIST[0]
# Out:
# ['서울시 상권분석서비스(상권영역).csv',
#  '서울시 상권분석서비스(상권배후지-아파트).csv',
#  '서울시 상권분석서비스(상권-소득소비).csv',
#  '서울시 상권분석서비스(상권-아파트).csv',
#  '서울시 상권분석서비스(상권배후지-직장인구).csv',
#  '서울시 상권분석서비스(상권배후지-점포).csv',
#  '서울시 상권분석서비스(상권-점포).csv',
#  '서울시 상권분석서비스(상권배후지-집객시설).csv',
#  '서울시 상권분석서비스(버스 총 승차 승객수 정보).csv',
#  '서울시 상권분석서비스(상권배후지-생활인구).csv',
#  '서울시 상권분석서비스(지하철 총 승차 승객수 정보).csv',
#  '서울시 상권분석서비스(상권-생활인구).csv',
#  '서울시 상권분석서비스(상권-직장인구).csv',
#  '서울시 상권분석서비스(행정동별 상권변화지표).csv']

# %% [markdown]
# ### 5.분기별 상권특성 공공데이터 전처리

# %% [markdown]
# #### 5.(1) 상권_소득소비
#
#   MARKET_2022_LIST[2]
#
#   MARKET_2023_LIST[1]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.교육_지출_총금액),
#     AVERAGE(seoul.상권특성.교통_지출_총금액),
#     AVERAGE(seoul.상권특성.생활용품_지출_총금액),
#     AVERAGE(seoul.상권특성.문화_지출_총금액),
#     AVERAGE(seoul.상권특성.유흥_지출_총금액),
#     AVERAGE(seoul.상권특성.의료비_지출_총금액),
#     AVERAGE(seoul.상권특성.의류_신발_지출_총금액),
#     AVERAGE(seoul.상권특성.식료품_지출_총금액),
#     AVERAGE(seoul.상권특성.여가_지출_총금액),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_no = seoul.상권특성.상권_코드
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6520 entries, 0 to 6519
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   기준_년_코드       6520 non-null   int64
#  1   기준_분기_코드      6520 non-null   int64
#  2   상권_구분_코드      6520 non-null   object
#  3   상권_구분_코드_명    6520 non-null   object
#  4   상권_코드         6520 non-null   int64
#  5   상권_코드_명       6520 non-null   object
#  6   월_평균_소득_금액    6480 non-null   float64
#  7   소득_구간_코드      6480 non-null   float64
#  8   지출_총금액        6388 non-null   float64
#  9   식료품_지출_총금액    6388 non-null   float64
#  10  의류_신발_지출_총금액  6388 non-null   float64
#  11  생활용품_지출_총금액   6388 non-null   float64
#  12  의료비_지출_총금액    6388 non-null   float64
#  13  교통_지출_총금액     6388 non-null   float64
#  14  여가_지출_총금액     6388 non-null   float64
#  15  문화_지출_총금액     6388 non-null   float64
#  16  교육_지출_총금액     6388 non-null   float64
#  17  유흥_지출_총금액     6388 non-null   float64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 917.0+ KB

# %% [markdown]
# #### 5.(2) 상권_배후지_아파트
#
#   MARKET_2022_LIST[3]
#
#   MARKET_2023_LIST[2]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.아파트_단지_수),
#     AVERAGE(seoul.상권특성.아파트_가격_1_억_미만_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_1_억_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_2_억_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_3_억_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_4_억_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_5_억_세대_수),
#     AVERAGE(seoul.상권특성.아파트_가격_6_억_이상_세대_수),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_nm = seoul.상권특성.상권_코드_명
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5932 entries, 0 to 5931
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   기준_년_코드             5932 non-null   int64
#  1   기준_분기_코드            5932 non-null   int64
#  2   상권_구분_코드            5932 non-null   object
#  3   상권_구분_코드_명          5932 non-null   object
#  4   상권_코드               5932 non-null   int64
#  5   상권_코드_명             5932 non-null   object
#  6   아파트_단지_수            5932 non-null   int64
#  7   아파트_가격_1_억_미만_세대_수  4720 non-null   float64
#  8   아파트_가격_1_억_세대_수     5520 non-null   float64
#  9   아파트_가격_2_억_세대_수     5440 non-null   float64
#  10  아파트_가격_3_억_세대_수     4232 non-null   float64
#  11  아파트_가격_4_억_세대_수     2984 non-null   float64
#  12  아파트_가격_5_억_세대_수     2120 non-null   float64
#  13  아파트_가격_6_억_이상_세대_수  1776 non-null   float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 648.9+ KB

# %% [markdown]
# #### 5.(3) 상권배후지_점포
#
#   MARKET_2022_LIST[6]
#
#   MARKET_2023_LIST[5]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.개업_점포_수),
#     AVERAGE(seoul.상권특성.유사_업종_점포_수),
#     AVERAGE(seoul.상권특성.폐업_점포_수),
#     AVERAGE(seoul.상권특성.점포_수),
#     AVERAGE(seoul.상권특성.프랜차이즈_점포_수),
#     STANDARD_DEVIATION_POPULATION(seoul.상권특성.개업_율),
#     STANDARD_DEVIATION_POPULATION(seoul.상권특성.폐업_율),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_nm = seoul.상권특성.상권_코드_명
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[6].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299665 entries, 0 to 299664
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   기준_년_코드      299665 non-null  int64
#  1   기준_분기_코드     299665 non-null  int64
#  2   상권_구분_코드     299665 non-null  object
#  3   상권_구분_코드_명   299665 non-null  object
#  4   상권_코드        299665 non-null  int64
#  5   상권_코드_명      299665 non-null  object
#  6   서비스_업종_코드    299665 non-null  object
#  7   서비스_업종_코드_명  299665 non-null  object
#  8   점포_수         299665 non-null  int64
#  9   유사_업종_점포_수   299665 non-null  int64
#  10  개업_율         299665 non-null  int64
#  11  개업_점포_수      299665 non-null  int64
#  12  폐업_률         299665 non-null  int64
#  13  폐업_점포_수      299665 non-null  int64
#  14  프랜차이즈_점포_수   299665 non-null  int64
# dtypes: int64(10), object(5)
# memory usage: 34.3+ MB

# %% [markdown]
# #### 5.(4) 상권배후지_집객시설
#
#   MARKET_2022_LIST[7]
#
#   MARKET_2023_LIST[6]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.집객시설_수),
#     AVERAGE(seoul.상권특성.관공서_수),
#     AVERAGE(seoul.상권특성.은행_수),
#     AVERAGE(seoul.상권특성.종합병원_수),
#     AVERAGE(seoul.상권특성.일반_병원_수),
#     AVERAGE(seoul.상권특성.약국_수),
#     AVERAGE(seoul.상권특성.유치원_수),
#     AVERAGE(seoul.상권특성.초등학교_수),
#     AVERAGE(seoul.상권특성.고등학교_수),
#     AVERAGE(seoul.상권특성.대학교_수),
#     AVERAGE(seoul.상권특성.백화점_수),
#     AVERAGE(seoul.상권특성.슈퍼마켓_수),
#     AVERAGE(seoul.상권특성.숙박_시설_수),AVERAGE(seoul.상권특성.버스_터미널_수),
#     AVERAGE(seoul.상권특성.지하철_역_수),
#     AVERAGE(seoul.상권특성.버스_정거장_수),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_no = seoul.상권특성.상권_코드
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[7].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4360 entries, 0 to 4359
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기준_년_코드     4360 non-null   int64
#  1   기준_분기_코드    4360 non-null   int64
#  2   상권_구분_코드    4360 non-null   object
#  3   상권_구분_코드_명  4360 non-null   object
#  4   상권_코드       4360 non-null   int64
#  5   상권_코드_명     4360 non-null   object
#  6   집객시설_수      4360 non-null   int64
#  7   관공서_수       4160 non-null   float64
#  8   은행_수        3684 non-null   float64
#  9   종합병원_수      540 non-null    float64
#  10  일반_병원_수     1472 non-null   float64
#  11  약국_수        4204 non-null   float64
#  12  유치원_수       2376 non-null   float64
#  13  초등학교_수      3336 non-null   float64
#  14  중학교_수       2180 non-null   float64
#  15  고등학교_수      1836 non-null   float64
#  16  대학교_수       1276 non-null   float64
#  17  백화점_수       52 non-null     float64
#  18  슈퍼마켓_수      904 non-null    float64
#  19  극장_수        8 non-null      float64
#  20  숙박_시설_수     1124 non-null   float64
#  21  공항_수        16 non-null     float64
#  22  철도_역_수      0 non-null      float64
#  23  버스_터미널_수    28 non-null     float64
#  24  지하철_역_수     2256 non-null   float64
#  25  버스_정거장_수    4360 non-null   int64
# dtypes: float64(18), int64(5), object(3)
# memory usage: 885.8+ KB

# %%
MARKET_2022_LIST[9].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4360 entries, 0 to 4359
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   기준_년_코드           4360 non-null   int64
#  1   기준_분기_코드          4360 non-null   int64
#  2   상권_구분_코드          4360 non-null   object
#  3   상권_구분_코드_명        4360 non-null   object
#  4   상권_코드             4360 non-null   int64
#  5   총_생활인구_수          4360 non-null   int64
#  6   남성_생활인구_수         4360 non-null   int64
#  7   여성_생활인구_수         4360 non-null   int64
#  8   연령대_10_생활인구_수     4360 non-null   int64
#  9   연령대_20_생활인구_수     4360 non-null   int64
#  10  연령대_30_생활인구_수     4360 non-null   int64
#  11  연령대_40_생활인구_수     4360 non-null   int64
#  12  연령대_50_생활인구_수     4360 non-null   int64
#  13  연령대_60_이상_생활인구_수  4360 non-null   int64
#  14  시간대_1_생활인구_수      4360 non-null   int64
#  15  시간대_2_생활인구_수      4360 non-null   int64
#  16  시간대_3_생활인구_수      4360 non-null   int64
#  17  시간대_4_생활인구_수      4360 non-null   int64
#  18  시간대_5_생활인구_수      4360 non-null   int64
#  19  시간대_6_생활인구_수      4360 non-null   int64
#  20  월요일_생활인구_수        4360 non-null   int64
#  21  화요일_생활인구_수        4360 non-null   int64
#  22  수요일_생활인구_수        4360 non-null   int64
#  23  목요일_생활인구_수        4360 non-null   int64
#  24  금요일_생활인구_수        4360 non-null   int64
#  25  토요일_생활인구_수        4360 non-null   int64
#  26  일요일_생활인구_수        4360 non-null   int64
# dtypes: int64(25), object(2)
# memory usage: 919.8+ KB

# %% [markdown]
# #### 5.(5) 상권_상주인구(상권-생활인구)
#
#   MARKET_2022_LIST[11]
#
#   MARKET_2022_LIST[10]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.연령대_10_상주인구_수),
#     AVERAGE(seoul.상권특성.연령대_20_상주인구_수),
#     AVERAGE(seoul.상권특성.연령대_30_상주인구_수),
#     AVERAGE(seoul.상권특성.연령대_40_상주인구_수),
#     AVERAGE(seoul.상권특성.연령대_50_상주인구_수),
#     AVERAGE(seoul.상권특성.연령대_60_이상_상주인구_수),
#     AVERAGE(seoul.상권특성.총_가구_수),
#     AVERAGE(seoul.상권특성.비_아파트_가구_수),
#     AVERAGE(seoul.상권특성.아파트_가구_수),
#     AVERAGE(seoul.상권특성.총_상주인구_수),
#     AVERAGE(seoul.상권특성.남성_상주인구_수),
#     AVERAGE(seoul.상권특성.여성_상주인구_수),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_no = seoul.상권특성.상권_코드
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[11].rename(columns = {" 상권_구분_코드_명":"상권_구분_코드_명"}, inplace = True)
MARKET_2023_LIST[10].rename(columns = {" 상권_구분_코드_명":"상권_구분_코드_명"}, inplace = True)

# %%
MARKET_2022_LIST[11].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6674 entries, 0 to 6673
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   기준_년_코드           6674 non-null   int64
#  1   기준_분기_코드          6674 non-null   int64
#  2   상권_구분_코드          6674 non-null   object
#  3   상권_구분_코드_명        6674 non-null   object
#  4   상권_코드             6674 non-null   int64
#  5   상권_코드_명           6674 non-null   object
#  6   총_생활인구_수          6674 non-null   int64
#  7   남성_생활인구_수         6674 non-null   int64
#  8   여성_생활인구_수         6674 non-null   int64
#  9   연령대_10_생활인구_수     6674 non-null   int64
#  10  연령대_20_생활인구_수     6674 non-null   int64
#  11  연령대_30_생활인구_수     6674 non-null   int64
#  12  연령대_40_생활인구_수     6674 non-null   int64
#  13  연령대_50_생활인구_수     6674 non-null   int64
#  14  연령대_60_이상_생활인구_수  6674 non-null   int64
#  15  시간대_1_생활인구_수      6674 non-null   int64
#  16  시간대_2_생활인구_수      6674 non-null   int64
#  17  시간대_3_생활인구_수      6674 non-null   int64
#  18  시간대_4_생활인구_수      6674 non-null   int64
#  19  시간대_5_생활인구_수      6674 non-null   int64
#  20  시간대_6_생활인구_수      6674 non-null   int64
#  21  월요일_생활인구_수        6674 non-null   int64
#  22  화요일_생활인구_수        6674 non-null   int64
#  23  수요일_생활인구_수        6674 non-null   int64
#  24  목요일_생활인구_수        6674 non-null   int64
#  25  금요일_생활인구_수        6674 non-null   int64
#  26  토요일_생활인구_수        6674 non-null   int64
#  27  일요일_생활인구_수        6674 non-null   int64
# dtypes: int64(25), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# #### 5.(6) 상권_점포(행정동별 상권변화지표)
#
#   ['상권축소', '정체', '다이나믹', '상권확장']
#
#   MARKET_2022_LIST[13]
#
#   MARKET_2023_LIST[12]
#
#   ```
#   SELECT
#     AVERAGE(seoul.상권특성.개업_점포_수),
#     AVERAGE(seoul.상권특성.유사_업종_점포_수),
#     AVERAGE(seoul.상권특성.폐업_점포_수),
#     AVERAGE(seoul.상권특성.점포_수),
#     AVERAGE(seoul.상권특성.프랜차이즈_점포_수),
#     STANDARD_DEVIATION_POPULATION(seoul.상권특성.개업_율),
#     STANDARD_DEVIATION_POPULATION(seoul.상권특성.폐업_율),
#     COUNT(*),
#     SUM(kcd.meta-info.is_franchise)
#   FROM kcd.meta-info
#   JOIN seoul.상권특성
#   ON kcd.meta-info.trdar_nm = seoul.상권특성.상권_코드_명
#   WHERE kcd.meta-info.class_1_name = "외식업"
#   GROUP BY seoul.상권특성.기준_년_코드, seoul.상권특성.기준_분기_코드, kcd.meta-info.class_2_name
#   ```

# %%
MARKET_2022_LIST[13].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1696 entries, 0 to 1695
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   기준_년_코드         1696 non-null   int64
#  1   기준_분기_코드        1696 non-null   int64
#  2   행정동_코드          1696 non-null   int64
#  3   행정동_코드_명        1696 non-null   object
#  4   상권_변화_지표        1696 non-null   object
#  5   상권_변화_지표_명      1696 non-null   object
#  6   운영_영업_개월_평균     1696 non-null   int64
#  7   폐업_영업_개월_평균     1696 non-null   int64
#  8   서울_운영_영업_개월_평균  1696 non-null   int64
#  9   서울_폐업_영업_개월_평균  1696 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 132.6+ KB

# %% [markdown]
# ___

# %%
for index in [2, 3, 6, 7, 11]:
  if index == 2:
    MERGE_2022_DATA = MARKET_2022_LIST[index]
  else:
    MERGE_2022_DATA = pd.merge(
        left = MERGE_2022_DATA, right = MARKET_2022_LIST[index],
        on = ["기준_년_코드", "기준_분기_코드", "상권_구분_코드", "상권_구분_코드_명", "상권_코드", "상권_코드_명"],
        how = "outer")

# %%
MARKET_2022_LIST[0].drop(["형태정보"], axis = 1, inplace = True)

# %%
MARKET_LOC_MAP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   상권_코드_2022   3458 non-null   int64
#  1   상권_코드_2023   3458 non-null   int64
#  2   행정동_코드       3458 non-null   int64
#  3   법정동_코드       3458 non-null   int64
#  4   STDG_EMD_CD  3458 non-null   int64
# dtypes: int64(5)
# memory usage: 135.2 KB

# %%
MARKET_2022_LIST[13] = pd.merge(
    left = MARKET_LOC_MAP, right = MARKET_2022_LIST[13],
    on = ["행정동_코드"],
    how = "right")

# %%
MARKET_2022_LIST[13].rename(columns = {"상권_코드_2022":"상권_코드"}, inplace = True)

# %%
MERGE_2022_DATA = pd.merge(
        left = MERGE_2022_DATA, right = MARKET_2022_LIST[13],
        on = ["기준_년_코드", "기준_분기_코드", "상권_코드"],
        how = "inner")

# %%
MERGE_2022_DATA = pd.merge(
        left = MERGE_2022_DATA, right = MARKET_2022_LIST[0][["상권_구분_코드", "상권_코드_명", "엑스좌표_값", "와이좌표_값", "시군구_코드", "행정동_코드"]],
        on = ["상권_구분_코드", "행정동_코드"],
        how = "left")

# %%
pd.set_option("display.max_column", None)

# %%
MERGE_2022_DATA
# Out:
#          기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명_x  \
# 0           2022         4        A       골목상권  2110001    이북5도청사
# 1           2022         4        A       골목상권  2110001    이북5도청사
# 2           2022         4        A       골목상권  2110001    이북5도청사
# 3           2022         4        A       골목상권  2110001    이북5도청사
# 4           2022         4        A       골목상권  2110001    이북5도청사
# ...          ...       ...      ...        ...      ...       ...
# 2188036     2022         1        A       골목상권  2110793    대림썬프라자
# 2188037     2022         1        A       골목상권  2110793    대림썬프라자
# 2188038     2022         1        A       골목상권  2110793    대림썬프라자
# 2188039     2022         1        A       골목상권  2110793    대림썬프라자
# 2188040     2022         1        A       골목상권  2110793    대림썬프라자
#
#           월_평균_소득_금액  소득_구간_코드         지출_총금액     식료품_지출_총금액  의류_신발_지출_총금액  \
# 0       4305934.0000    8.0000 520427635.0000 129126028.0000 64853632.0000
# 1       4305934.0000    8.0000 520427635.0000 129126028.0000 64853632.0000
# 2       4305934.0000    8.0000 520427635.0000 129126028.0000 64853632.0000
# 3       4305934.0000    8.0000 520427635.0000 129126028.0000 64853632.0000
# 4       4305934.0000    8.0000 520427635.0000 129126028.0000 64853632.0000
# ...              ...       ...            ...            ...           ...
# 2188036          NaN       NaN            NaN            NaN           NaN
# 2188037          NaN       NaN            NaN            NaN           NaN
# 2188038          NaN       NaN            NaN            NaN           NaN
# 2188039          NaN       NaN            NaN            NaN           NaN
# 2188040          NaN       NaN            NaN            NaN           NaN
#
#           생활용품_지출_총금액    의료비_지출_총금액     교통_지출_총금액     여가_지출_총금액     문화_지출_총금액  \
# 0       37122367.0000 65974602.0000 88343761.0000 22223650.0000 14656697.0000
# 1       37122367.0000 65974602.0000 88343761.0000 22223650.0000 14656697.0000
# 2       37122367.0000 65974602.0000 88343761.0000 22223650.0000 14656697.0000
# 3       37122367.0000 65974602.0000 88343761.0000 22223650.0000 14656697.0000
# 4       37122367.0000 65974602.0000 88343761.0000 22223650.0000 14656697.0000
# ...               ...           ...           ...           ...           ...
# 2188036           NaN           NaN           NaN           NaN           NaN
# 2188037           NaN           NaN           NaN           NaN           NaN
# 2188038           NaN           NaN           NaN           NaN           NaN
# 2188039           NaN           NaN           NaN           NaN           NaN
# 2188040           NaN           NaN           NaN           NaN           NaN
#
#             교육_지출_총금액     유흥_지출_총금액  아파트_단지_수  아파트_가격_1_억_미만_세대_수  \
# 0       76185341.0000 21941557.0000   21.0000             11.0000
# 1       76185341.0000 21941557.0000   21.0000             11.0000
# 2       76185341.0000 21941557.0000   21.0000             11.0000
# 3       76185341.0000 21941557.0000   21.0000             11.0000
# 4       76185341.0000 21941557.0000   21.0000             11.0000
# ...               ...           ...       ...                 ...
# 2188036           NaN           NaN       NaN                 NaN
# 2188037           NaN           NaN       NaN                 NaN
# 2188038           NaN           NaN       NaN                 NaN
# 2188039           NaN           NaN       NaN                 NaN
# 2188040           NaN           NaN       NaN                 NaN
#
#          아파트_가격_1_억_세대_수  아파트_가격_2_억_세대_수  아파트_가격_3_억_세대_수  아파트_가격_4_억_세대_수  \
# 0                 4.0000          35.0000         105.0000         111.0000
# 1                 4.0000          35.0000         105.0000         111.0000
# 2                 4.0000          35.0000         105.0000         111.0000
# 3                 4.0000          35.0000         105.0000         111.0000
# 4                 4.0000          35.0000         105.0000         111.0000
# ...                  ...              ...              ...              ...
# 2188036              NaN              NaN              NaN              NaN
# 2188037              NaN              NaN              NaN              NaN
# 2188038              NaN              NaN              NaN              NaN
# 2188039              NaN              NaN              NaN              NaN
# 2188040              NaN              NaN              NaN              NaN
#
#          아파트_가격_5_억_세대_수  아파트_가격_6_억_이상_세대_수 서비스_업종_코드 서비스_업종_코드_명   점포_수  \
# 0                25.0000             59.0000  CS300043      전자상거래업 1.0000
# 1                25.0000             59.0000  CS300043      전자상거래업 1.0000
# 2                25.0000             59.0000  CS300043      전자상거래업 1.0000
# 3                25.0000             59.0000  CS300043      전자상거래업 1.0000
# 4                25.0000             59.0000  CS300043      전자상거래업 1.0000
# ...                  ...                 ...       ...         ...    ...
# 2188036              NaN                 NaN  CS100001       한식음식점 3.0000
# 2188037              NaN                 NaN  CS100001       한식음식점 3.0000
# 2188038              NaN                 NaN  CS100001       한식음식점 3.0000
# 2188039              NaN                 NaN  CS100001       한식음식점 3.0000
# 2188040              NaN                 NaN  CS100001       한식음식점 3.0000
#
#          유사_업종_점포_수   개업_율  개업_점포_수   폐업_률  폐업_점포_수  프랜차이즈_점포_수  집객시설_수  \
# 0            1.0000 0.0000   0.0000 0.0000   0.0000      0.0000 42.0000
# 1            1.0000 0.0000   0.0000 0.0000   0.0000      0.0000 42.0000
# 2            1.0000 0.0000   0.0000 0.0000   0.0000      0.0000 42.0000
# 3            1.0000 0.0000   0.0000 0.0000   0.0000      0.0000 42.0000
# 4            1.0000 0.0000   0.0000 0.0000   0.0000      0.0000 42.0000
# ...             ...    ...      ...    ...      ...         ...     ...
# 2188036      4.0000 0.0000   0.0000 0.0000   0.0000      1.0000 50.0000
# 2188037      4.0000 0.0000   0.0000 0.0000   0.0000      1.0000 50.0000
# 2188038      4.0000 0.0000   0.0000 0.0000   0.0000      1.0000 50.0000
# 2188039      4.0000 0.0000   0.0000 0.0000   0.0000      1.0000 50.0000
# 2188040      4.0000 0.0000   0.0000 0.0000   0.0000      1.0000 50.0000
#
#          관공서_수   은행_수  종합병원_수  일반_병원_수   약국_수  유치원_수  초등학교_수  중학교_수  고등학교_수  \
# 0       2.0000    NaN     NaN      NaN 2.0000    NaN     NaN    NaN     NaN
# 1       2.0000    NaN     NaN      NaN 2.0000    NaN     NaN    NaN     NaN
# 2       2.0000    NaN     NaN      NaN 2.0000    NaN     NaN    NaN     NaN
# 3       2.0000    NaN     NaN      NaN 2.0000    NaN     NaN    NaN     NaN
# 4       2.0000    NaN     NaN      NaN 2.0000    NaN     NaN    NaN     NaN
# ...        ...    ...     ...      ...    ...    ...     ...    ...     ...
# 2188036 2.0000 1.0000  1.0000      NaN 8.0000    NaN     NaN    NaN  1.0000
# 2188037 2.0000 1.0000  1.0000      NaN 8.0000    NaN     NaN    NaN  1.0000
# 2188038 2.0000 1.0000  1.0000      NaN 8.0000    NaN     NaN    NaN  1.0000
# 2188039 2.0000 1.0000  1.0000      NaN 8.0000    NaN     NaN    NaN  1.0000
# 2188040 2.0000 1.0000  1.0000      NaN 8.0000    NaN     NaN    NaN  1.0000
#
#          대학교_수  백화점_수  슈퍼마켓_수  극장_수  숙박_시설_수  공항_수  철도_역_수  버스_터미널_수  지하철_역_수  \
# 0          NaN    NaN     NaN   NaN      NaN   NaN     NaN       NaN      NaN
# 1          NaN    NaN     NaN   NaN      NaN   NaN     NaN       NaN      NaN
# 2          NaN    NaN     NaN   NaN      NaN   NaN     NaN       NaN      NaN
# 3          NaN    NaN     NaN   NaN      NaN   NaN     NaN       NaN      NaN
# 4          NaN    NaN     NaN   NaN      NaN   NaN     NaN       NaN      NaN
# ...        ...    ...     ...   ...      ...   ...     ...       ...      ...
# 2188036    NaN    NaN  2.0000   NaN   6.0000   NaN     NaN       NaN      NaN
# 2188037    NaN    NaN  2.0000   NaN   6.0000   NaN     NaN       NaN      NaN
# 2188038    NaN    NaN  2.0000   NaN   6.0000   NaN     NaN       NaN      NaN
# 2188039    NaN    NaN  2.0000   NaN   6.0000   NaN     NaN       NaN      NaN
# 2188040    NaN    NaN  2.0000   NaN   6.0000   NaN     NaN       NaN      NaN
#
#          버스_정거장_수    총_생활인구_수  남성_생활인구_수   여성_생활인구_수  연령대_10_생활인구_수  \
# 0         24.0000 179890.0000 77520.0000 102371.0000     32520.0000
# 1         24.0000 179890.0000 77520.0000 102371.0000     32520.0000
# 2         24.0000 179890.0000 77520.0000 102371.0000     32520.0000
# 3         24.0000 179890.0000 77520.0000 102371.0000     32520.0000
# 4         24.0000 179890.0000 77520.0000 102371.0000     32520.0000
# ...           ...         ...        ...         ...            ...
# 2188036   11.0000  32622.0000 15240.0000  17383.0000      4572.0000
# 2188037   11.0000  32622.0000 15240.0000  17383.0000      4572.0000
# 2188038   11.0000  32622.0000 15240.0000  17383.0000      4572.0000
# 2188039   11.0000  32622.0000 15240.0000  17383.0000      4572.0000
# 2188040   11.0000  32622.0000 15240.0000  17383.0000      4572.0000
#
#          연령대_20_생활인구_수  연령대_30_생활인구_수  연령대_40_생활인구_수  연령대_50_생활인구_수  \
# 0           19380.0000     18694.0000     27893.0000     28419.0000
# 1           19380.0000     18694.0000     27893.0000     28419.0000
# 2           19380.0000     18694.0000     27893.0000     28419.0000
# 3           19380.0000     18694.0000     27893.0000     28419.0000
# 4           19380.0000     18694.0000     27893.0000     28419.0000
# ...                ...            ...            ...            ...
# 2188036      3915.0000      5666.0000      5409.0000      5335.0000
# 2188037      3915.0000      5666.0000      5409.0000      5335.0000
# 2188038      3915.0000      5666.0000      5409.0000      5335.0000
# 2188039      3915.0000      5666.0000      5409.0000      5335.0000
# 2188040      3915.0000      5666.0000      5409.0000      5335.0000
#
#          연령대_60_이상_생활인구_수  시간대_1_생활인구_수  시간대_2_생활인구_수  시간대_3_생활인구_수  \
# 0              52986.0000    46661.0000    38082.0000    20225.0000
# 1              52986.0000    46661.0000    38082.0000    20225.0000
# 2              52986.0000    46661.0000    38082.0000    20225.0000
# 3              52986.0000    46661.0000    38082.0000    20225.0000
# 4              52986.0000    46661.0000    38082.0000    20225.0000
# ...                   ...           ...           ...           ...
# 2188036         7728.0000     5530.0000     6800.0000     4890.0000
# 2188037         7728.0000     5530.0000     6800.0000     4890.0000
# 2188038         7728.0000     5530.0000     6800.0000     4890.0000
# 2188039         7728.0000     5530.0000     6800.0000     4890.0000
# 2188040         7728.0000     5530.0000     6800.0000     4890.0000
#
#          시간대_4_생활인구_수  시간대_5_생활인구_수  시간대_6_생활인구_수  월요일_생활인구_수  화요일_생활인구_수  \
# 0          21164.0000    29951.0000    23808.0000  25766.0000  24959.0000
# 1          21164.0000    29951.0000    23808.0000  25766.0000  24959.0000
# 2          21164.0000    29951.0000    23808.0000  25766.0000  24959.0000
# 3          21164.0000    29951.0000    23808.0000  25766.0000  24959.0000
# 4          21164.0000    29951.0000    23808.0000  25766.0000  24959.0000
# ...               ...           ...           ...         ...         ...
# 2188036     5186.0000     6633.0000     3584.0000   4560.0000   4545.0000
# 2188037     5186.0000     6633.0000     3584.0000   4560.0000   4545.0000
# 2188038     5186.0000     6633.0000     3584.0000   4560.0000   4545.0000
# 2188039     5186.0000     6633.0000     3584.0000   4560.0000   4545.0000
# 2188040     5186.0000     6633.0000     3584.0000   4560.0000   4545.0000
#
#          수요일_생활인구_수  목요일_생활인구_수  금요일_생활인구_수  토요일_생활인구_수  일요일_생활인구_수  \
# 0        24786.0000  25388.0000  24645.0000  26979.0000  27365.0000
# 1        24786.0000  25388.0000  24645.0000  26979.0000  27365.0000
# 2        24786.0000  25388.0000  24645.0000  26979.0000  27365.0000
# 3        24786.0000  25388.0000  24645.0000  26979.0000  27365.0000
# 4        24786.0000  25388.0000  24645.0000  26979.0000  27365.0000
# ...             ...         ...         ...         ...         ...
# 2188036   4651.0000   4604.0000   4602.0000   4743.0000   4917.0000
# 2188037   4651.0000   4604.0000   4602.0000   4743.0000   4917.0000
# 2188038   4651.0000   4604.0000   4602.0000   4743.0000   4917.0000
# 2188039   4651.0000   4604.0000   4602.0000   4743.0000   4917.0000
# 2188040   4651.0000   4604.0000   4602.0000   4743.0000   4917.0000
#
#           상권_코드_2023    행정동_코드        법정동_코드   STDG_EMD_CD 행정동_코드_명 상권_변화_지표  \
# 0       3110001.0000  11110560 11110182.0000 11110182.0000      평창동       HH
# 1       3110001.0000  11110560 11110182.0000 11110182.0000      평창동       HH
# 2       3110001.0000  11110560 11110182.0000 11110182.0000      평창동       HH
# 3       3110001.0000  11110560 11110183.0000 11110183.0000      평창동       HH
# 4       3110001.0000  11110560 11110183.0000 11110183.0000      평창동       HH
# ...              ...       ...           ...           ...      ...      ...
# 2188036 3110793.0000  11560700 11560133.0000 11560133.0000     대림1동       HL
# 2188037 3110793.0000  11560700 11560133.0000 11560133.0000     대림1동       HL
# 2188038 3110793.0000  11560700 11560133.0000 11560133.0000     대림1동       HL
# 2188039 3110793.0000  11560700 11560133.0000 11560133.0000     대림1동       HL
# 2188040 3110793.0000  11560700 11560133.0000 11560133.0000     대림1동       HL
#
#         상권_변화_지표_명  운영_영업_개월_평균  폐업_영업_개월_평균  서울_운영_영업_개월_평균  서울_폐업_영업_개월_평균  \
# 0               정체          131           63             123              56
# 1               정체          131           63             123              56
# 2               정체          131           63             123              56
# 3               정체          131           63             123              56
# 4               정체          131           63             123              56
# ...            ...          ...          ...             ...             ...
# 2188036       상권축소          127           52             119              55
# 2188037       상권축소          127           52             119              55
# 2188038       상권축소          127           52             119              55
# 2188039       상권축소          127           52             119              55
# 2188040       상권축소          127           52             119              55
#
#          상권_코드_명_y  엑스좌표_값  와이좌표_값  시군구_코드
# 0            평창동서측  197064  456643   11110
# 1           이북5도청사  196262  456660   11110
# 2            평창동동측  197827  457040   11110
# 3            평창동서측  197064  456643   11110
# 4           이북5도청사  196262  456660   11110
# ...            ...     ...     ...     ...
# 2188036    대림한신아파트  191471  443882   11560
# 2188037     대림썬프라자  191840  444066   11560
# 2188038  대림갑을명가아파트  191416  444092   11560
# 2188039    신대림초등학교  191504  443609   11560
# 2188040     대림성모병원  191713  443474   11560
#
# [2188041 rows x 92 columns]

# %%
MERGE_2022_DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2188041 entries, 0 to 2188040
# Data columns (total 92 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   기준_년_코드             int64
#  1   기준_분기_코드            int64
#  2   상권_구분_코드            object
#  3   상권_구분_코드_명          object
#  4   상권_코드               int64
#  5   상권_코드_명_x           object
#  6   월_평균_소득_금액          float64
#  7   소득_구간_코드            float64
#  8   지출_총금액              float64
#  9   식료품_지출_총금액          float64
#  10  의류_신발_지출_총금액        float64
#  11  생활용품_지출_총금액         float64
#  12  의료비_지출_총금액          float64
#  13  교통_지출_총금액           float64
#  14  여가_지출_총금액           float64
#  15  문화_지출_총금액           float64
#  16  교육_지출_총금액           float64
#  17  유흥_지출_총금액           float64
#  18  아파트_단지_수            float64
#  19  아파트_가격_1_억_미만_세대_수  float64
#  20  아파트_가격_1_억_세대_수     float64
#  21  아파트_가격_2_억_세대_수     float64
#  22  아파트_가격_3_억_세대_수     float64
#  23  아파트_가격_4_억_세대_수     float64
#  24  아파트_가격_5_억_세대_수     float64
#  25  아파트_가격_6_억_이상_세대_수  float64
#  26  서비스_업종_코드           object
#  27  서비스_업종_코드_명         object
#  28  점포_수                float64
#  29  유사_업종_점포_수          float64
#  30  개업_율                float64
#  31  개업_점포_수             float64
#  32  폐업_률                float64
#  33  폐업_점포_수             float64
#  34  프랜차이즈_점포_수          float64
#  35  집객시설_수              float64
#  36  관공서_수               float64
#  37  은행_수                float64
#  38  종합병원_수              float64
#  39  일반_병원_수             float64
#  40  약국_수                float64
#  41  유치원_수               float64
#  42  초등학교_수              float64
#  43  중학교_수               float64
#  44  고등학교_수              float64
#  45  대학교_수               float64
#  46  백화점_수               float64
#  47  슈퍼마켓_수              float64
#  48  극장_수                float64
#  49  숙박_시설_수             float64
#  50  공항_수                float64
#  51  철도_역_수              float64
#  52  버스_터미널_수            float64
#  53  지하철_역_수             float64
#  54  버스_정거장_수            float64
#  55  총_생활인구_수            float64
#  56  남성_생활인구_수           float64
#  57  여성_생활인구_수           float64
#  58  연령대_10_생활인구_수       float64
#  59  연령대_20_생활인구_수       float64
#  60  연령대_30_생활인구_수       float64
#  61  연령대_40_생활인구_수       float64
#  62  연령대_50_생활인구_수       float64
#  63  연령대_60_이상_생활인구_수    float64
#  64  시간대_1_생활인구_수        float64
#  65  시간대_2_생활인구_수        float64
#  66  시간대_3_생활인구_수        float64
#  67  시간대_4_생활인구_수        float64
#  68  시간대_5_생활인구_수        float64
#  69  시간대_6_생활인구_수        float64
#  70  월요일_생활인구_수          float64
#  71  화요일_생활인구_수          float64
#  72  수요일_생활인구_수          float64
#  73  목요일_생활인구_수          float64
#  74  금요일_생활인구_수          float64
#  75  토요일_생활인구_수          float64
#  76  일요일_생활인구_수          float64
#  77  상권_코드_2023          float64
#  78  행정동_코드              int64
#  79  법정동_코드              float64
#  80  STDG_EMD_CD         float64
#  81  행정동_코드_명            object
#  82  상권_변화_지표            object
#  83  상권_변화_지표_명          object
#  84  운영_영업_개월_평균         int64
#  85  폐업_영업_개월_평균         int64
#  86  서울_운영_영업_개월_평균      int64
#  87  서울_폐업_영업_개월_평균      int64
#  88  상권_코드_명_y           object
#  89  엑스좌표_값              int64
#  90  와이좌표_값              int64
#  91  시군구_코드              int64
# dtypes: float64(72), int64(11), object(9)
# memory usage: 1.5+ GB

# %%
# MERGE_2022_DATA.to_csv("/content/drive/MyDrive/2023BigContest/data/DESILO_PLATFORM_DATA/MARKET_MERGE_2022_RAW_DATA.csv", index = False)

# %% [markdown]
# ___

# %%
for index in [1, 2, 5, 6, 10]:
  if index == 1:
    MERGE_2023_DATA = MARKET_2023_LIST[index]
  else:
    MERGE_2023_DATA = pd.merge(
        left = MERGE_2023_DATA, right = MARKET_2023_LIST[index],
        on = ["기준_년_코드", "기준_분기_코드", "상권_구분_코드", "상권_구분_코드_명", "상권_코드", "상권_코드_명"],
        how = "outer")

# %%
MARKET_2023_LIST[10]
MERGE_2023_DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77793 entries, 0 to 77792
# Data columns (total 77 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   기준_년_코드             77793 non-null  int64
#  1   기준_분기_코드            77793 non-null  int64
#  2   상권_구분_코드            77793 non-null  object
#  3   상권_구분_코드_명          77793 non-null  object
#  4   상권_코드               77793 non-null  int64
#  5   상권_코드_명             2114 non-null   object
#  6   월_평균_소득_금액          0 non-null      float64
#  7   소득_구간_코드            0 non-null      float64
#  8   지출_총금액              1592 non-null   float64
#  9   식료품_지출_총금액          1592 non-null   float64
#  10  의류_신발_지출_총금액        1592 non-null   float64
#  11  생활용품_지출_총금액         1592 non-null   float64
#  12  의료비_지출_총금액          1592 non-null   float64
#  13  교통_지출_총금액           1592 non-null   float64
#  14  여가_지출_총금액           1592 non-null   float64
#  15  문화_지출_총금액           1592 non-null   float64
#  16  교육_지출_총금액           1592 non-null   float64
#  17  유흥_지출_총금액           1592 non-null   float64
#  18  아파트_단지_수            69952 non-null  float64
#  19  아파트_가격_1_억_미만_세대_수  56286 non-null  float64
#  20  아파트_가격_1_억_세대_수     65395 non-null  float64
#  21  아파트_가격_2_억_세대_수     64404 non-null  float64
#  22  아파트_가격_3_억_세대_수     49558 non-null  float64
#  23  아파트_가격_4_억_세대_수     34924 non-null  float64
#  24  아파트_가격_5_억_세대_수     25060 non-null  float64
#  25  아파트_가격_6_억_이상_세대_수  21812 non-null  float64
#  26  서비스_업종_코드           76189 non-null  object
#  27  서비스_업종_코드_명         76189 non-null  object
#  28  점포_수                76189 non-null  float64
#  29  유사_업종_점포_수          76189 non-null  float64
#  30  개업_율                76189 non-null  float64
#  31  개업_점포_수             76189 non-null  float64
#  32  폐업_률                76189 non-null  float64
#  33  폐업_점포_수             76189 non-null  float64
#  34  프랜차이즈_점포_수          76189 non-null  float64
#  35  집객시설_수              1090 non-null   float64
#  36  관공서_수               1040 non-null   float64
#  37  은행_수                921 non-null    float64
#  38  종합병원_수              135 non-null    float64
#  39  일반_병원_수             368 non-null    float64
#  40  약국_수                1051 non-null   float64
#  41  유치원_수               594 non-null    float64
#  42  초등학교_수              834 non-null    float64
#  43  중학교_수               545 non-null    float64
#  44  고등학교_수              459 non-null    float64
#  45  대학교_수               319 non-null    float64
#  46  백화점_수               13 non-null     float64
#  47  슈퍼마켓_수              226 non-null    float64
#  48  극장_수                2 non-null      float64
#  49  숙박_시설_수             281 non-null    float64
#  50  공항_수                4 non-null      float64
#  51  철도_역_수              0 non-null      float64
#  52  버스_터미널_수            7 non-null      float64
#  53  지하철_역_수             564 non-null    float64
#  54  버스_정거장_수            1090 non-null   float64
#  55  총_생활인구_수            76178 non-null  float64
#  56  남성_생활인구_수           76178 non-null  float64
#  57  여성_생활인구_수           76178 non-null  float64
#  58  연령대_10_생활인구_수       76178 non-null  float64
#  59  연령대_20_생활인구_수       76178 non-null  float64
#  60  연령대_30_생활인구_수       76178 non-null  float64
#  61  연령대_40_생활인구_수       76178 non-null  float64
#  62  연령대_50_생활인구_수       76178 non-null  float64
#  63  연령대_60_이상_생활인구_수    76178 non-null  float64
#  64  시간대_1_생활인구_수        76178 non-null  float64
#  65  시간대_2_생활인구_수        76178 non-null  float64
#  66  시간대_3_생활인구_수        76178 non-null  float64
#  67  시간대_4_생활인구_수        76178 non-null  float64
#  68  시간대_5_생활인구_수        76178 non-null  float64
#  69  시간대_6_생활인구_수        76178 non-null  float64
#  70  월요일_생활인구_수          76178 non-null  float64
#  71  화요일_생활인구_수          76178 non-null  float64
#  72  수요일_생활인구_수          76178 non-null  float64
#  73  목요일_생활인구_수          76178 non-null  float64
#  74  금요일_생활인구_수          76178 non-null  float64
#  75  토요일_생활인구_수          76178 non-null  float64
#  76  일요일_생활인구_수          76178 non-null  float64
# dtypes: float64(69), int64(3), object(5)
# memory usage: 46.3+ MB

# %%
MARKET_LOC_MAP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   상권_코드_2022   3458 non-null   int64
#  1   상권_코드_2023   3458 non-null   int64
#  2   행정동_코드       3458 non-null   int64
#  3   법정동_코드       3458 non-null   int64
#  4   STDG_EMD_CD  3458 non-null   int64
# dtypes: int64(5)
# memory usage: 135.2 KB

# %%
MARKET_2023_LIST[12] = pd.merge(
    left = MARKET_LOC_MAP, right = MARKET_2023_LIST[12],
    on = ["행정동_코드"],
    how = "right")

# %%
MARKET_2023_LIST[12].rename(columns = {"상권_코드_2023":"상권_코드"}, inplace = True)

# %%
MARKET_2023_LIST[12].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3487 entries, 0 to 3486
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   상권_코드_2022      3458 non-null   float64
#  1   상권_코드           3458 non-null   float64
#  2   행정동_코드          3487 non-null   int64
#  3   법정동_코드          3458 non-null   float64
#  4   STDG_EMD_CD     3458 non-null   float64
#  5   기준_년_코드         3487 non-null   int64
#  6   기준_분기_코드        3487 non-null   int64
#  7   행정동_코드_명        3487 non-null   object
#  8   상권_변화_지표        3487 non-null   object
#  9   상권_변화_지표_명      3487 non-null   object
#  10  운영_영업_개월_평균     3487 non-null   int64
#  11  폐업_영업_개월_평균     3487 non-null   int64
#  12  서울_운영_영업_개월_평균  3487 non-null   int64
#  13  서울_폐업_영업_개월_평균  3487 non-null   int64
# dtypes: float64(4), int64(7), object(3)
# memory usage: 408.6+ KB

# %%
MERGE_2023_DATA = pd.merge(
        left = MERGE_2023_DATA, right = MARKET_2023_LIST[12],
        on = ["기준_년_코드", "기준_분기_코드", "상권_코드"],
        how = "outer")

# %%
MERGE_2023_DATA = pd.merge(
        left = MERGE_2023_DATA, right = MARKET_2022_LIST[0][["상권_구분_코드", "상권_코드_명", "엑스좌표_값", "와이좌표_값", "시군구_코드", "행정동_코드"]],
        on = ["상권_구분_코드", "행정동_코드"],
        how = "left")

# %%
MERGE_2023_DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 575905 entries, 0 to 575904
# Data columns (total 92 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   기준_년_코드             575905 non-null  int64
#  1   기준_분기_코드            575905 non-null  int64
#  2   상권_구분_코드            575876 non-null  object
#  3   상권_구분_코드_명          575876 non-null  object
#  4   상권_코드               575876 non-null  float64
#  5   상권_코드_명_x           16475 non-null   object
#  6   월_평균_소득_금액          0 non-null       float64
#  7   소득_구간_코드            0 non-null       float64
#  8   지출_총금액              11534 non-null   float64
#  9   식료품_지출_총금액          11534 non-null   float64
#  10  의류_신발_지출_총금액        11534 non-null   float64
#  11  생활용품_지출_총금액         11534 non-null   float64
#  12  의료비_지출_총금액          11534 non-null   float64
#  13  교통_지출_총금액           11534 non-null   float64
#  14  여가_지출_총금액           11534 non-null   float64
#  15  문화_지출_총금액           11534 non-null   float64
#  16  교육_지출_총금액           11534 non-null   float64
#  17  유흥_지출_총금액           11534 non-null   float64
#  18  아파트_단지_수            405876 non-null  float64
#  19  아파트_가격_1_억_미만_세대_수  307431 non-null  float64
#  20  아파트_가격_1_억_세대_수     369176 non-null  float64
#  21  아파트_가격_2_억_세대_수     356505 non-null  float64
#  22  아파트_가격_3_억_세대_수     280374 non-null  float64
#  23  아파트_가격_4_억_세대_수     203863 non-null  float64
#  24  아파트_가격_5_억_세대_수     139945 non-null  float64
#  25  아파트_가격_6_억_이상_세대_수  133898 non-null  float64
#  26  서비스_업종_코드           564223 non-null  object
#  27  서비스_업종_코드_명         564223 non-null  object
#  28  점포_수                564223 non-null  float64
#  29  유사_업종_점포_수          564223 non-null  float64
#  30  개업_율                564223 non-null  float64
#  31  개업_점포_수             564223 non-null  float64
#  32  폐업_률                564223 non-null  float64
#  33  폐업_점포_수             564223 non-null  float64
#  34  프랜차이즈_점포_수          564223 non-null  float64
#  35  집객시설_수              6961 non-null    float64
#  36  관공서_수               6694 non-null    float64
#  37  은행_수                6055 non-null    float64
#  38  종합병원_수              1078 non-null    float64
#  39  일반_병원_수             1993 non-null    float64
#  40  약국_수                6566 non-null    float64
#  41  유치원_수               3220 non-null    float64
#  42  초등학교_수              5213 non-null    float64
#  43  중학교_수               3302 non-null    float64
#  44  고등학교_수              3024 non-null    float64
#  45  대학교_수               2641 non-null    float64
#  46  백화점_수               69 non-null      float64
#  47  슈퍼마켓_수              1145 non-null    float64
#  48  극장_수                5 non-null       float64
#  49  숙박_시설_수             2156 non-null    float64
#  50  공항_수                96 non-null      float64
#  51  철도_역_수              0 non-null       float64
#  52  버스_터미널_수            22 non-null      float64
#  53  지하철_역_수             3813 non-null    float64
#  54  버스_정거장_수            6961 non-null    float64
#  55  총_생활인구_수            564076 non-null  float64
#  56  남성_생활인구_수           564076 non-null  float64
#  57  여성_생활인구_수           564076 non-null  float64
#  58  연령대_10_생활인구_수       564076 non-null  float64
#  59  연령대_20_생활인구_수       564076 non-null  float64
#  60  연령대_30_생활인구_수       564076 non-null  float64
#  61  연령대_40_생활인구_수       564076 non-null  float64
#  62  연령대_50_생활인구_수       564076 non-null  float64
#  63  연령대_60_이상_생활인구_수    564076 non-null  float64
#  64  시간대_1_생활인구_수        564076 non-null  float64
#  65  시간대_2_생활인구_수        564076 non-null  float64
#  66  시간대_3_생활인구_수        564076 non-null  float64
#  67  시간대_4_생활인구_수        564076 non-null  float64
#  68  시간대_5_생활인구_수        564076 non-null  float64
#  69  시간대_6_생활인구_수        564076 non-null  float64
#  70  월요일_생활인구_수          564076 non-null  float64
#  71  화요일_생활인구_수          564076 non-null  float64
#  72  수요일_생활인구_수          564076 non-null  float64
#  73  목요일_생활인구_수          564076 non-null  float64
#  74  금요일_생활인구_수          564076 non-null  float64
#  75  토요일_생활인구_수          564076 non-null  float64
#  76  일요일_생활인구_수          564076 non-null  float64
#  77  상권_코드_2022          574675 non-null  float64
#  78  행정동_코드              574704 non-null  float64
#  79  법정동_코드              574675 non-null  float64
#  80  STDG_EMD_CD         574675 non-null  float64
#  81  행정동_코드_명            574704 non-null  object
#  82  상권_변화_지표            574704 non-null  object
#  83  상권_변화_지표_명          574704 non-null  object
#  84  운영_영업_개월_평균         574704 non-null  float64
#  85  폐업_영업_개월_평균         574704 non-null  float64
#  86  서울_운영_영업_개월_평균      574704 non-null  float64
#  87  서울_폐업_영업_개월_평균      574704 non-null  float64
#  88  상권_코드_명_y           574675 non-null  object
#  89  엑스좌표_값              574675 non-null  float64
#  90  와이좌표_값              574675 non-null  float64
#  91  시군구_코드              574675 non-null  float64
# dtypes: float64(81), int64(2), object(9)
# memory usage: 408.6+ MB

# %%
# MERGE_2023_DATA.to_csv("/content/drive/MyDrive/2023BigContest/data/DESILO_PLATFORM_DATA/MARKET_MERGE_2023_RAW_DATA.csv", index = False)
